# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
x = np.linspace(0,10,210)
plt.plot(x, np.sin(x))
plt.plot(x,np.sin(2*x))
